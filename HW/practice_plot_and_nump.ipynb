# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import numpy as np 
import matplotlib.pyplot as plt

random1 = np.random.normal(size = 200)#Draw random samples from a normal (Gaussian) distribution.
num = np.random.uniform(size = 10) #numpy.random.uniform(low=0.0, high=1.0, size=None) Draw samples from a uniform distribution

plt.hist(random1) #hist直方圖
plt.show()
plt.hist(num)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 目標函數:y=x^2
def func(x): return np.square(x)

# 目標函數一階導數:dy/dx=2*x
def dfunc(x): return 2 * x

def GD(x_start, df, epochs, lr):    
    """  梯度下降法。給定起始點與目標函數的一階導函數，求在epochs次反覆運算中x的更新值
        :param x_start: x的起始點    
        :param df: 目標函數的一階導函數    
        :param epochs: 反覆運算週期    
        :param lr: 學習率    
        :return: x在每次反覆運算後的位置（包括起始點），長度為epochs+1    
     """    
    xs = np.zeros(epochs+1)    
    x = x_start    
    xs[0] = x    
    for i in range(epochs):         
        dx = df(x)        
        # v表示x要改變的幅度        
        v = - dx * lr        
        x += v        
        xs[i+1] = x    
    return xs

# Main
# 起始權重
x_start = 5    
# 執行週期數
epochs = 6 
# 學習率   
lr = 0.3   
# 梯度下降法 
x = GD(x_start, dfunc, epochs, lr=lr) 
print (x)
# 輸出結果

color = 'r'    

from numpy import arange
t = arange(-6.0, 6.0, 0.01)
plt.plot(t, func(t), c='b') #線條圖
plt.plot(x, func(x), c=color, label='lr={}'.format(lr))    
plt.scatter(x, func(x), c=color, )    
plt.legend()

plt.show()
# Out:
# [5.      2.      0.8     0.32    0.128   0.0512  0.02048]

# %%
from sklearn.cluster import KMeans
from sklearn.externals import joblib
from sklearn import cluster
import numpy as np
import matplotlib.pyplot as plt
 
data = np.random.rand(10,2) #50*2的矩陣
print(data)
estimator=KMeans(n_clusters=3)#分3類
res=estimator.fit_predict(data)
lable_pred=estimator.labels_ 
centroids=estimator.cluster_centers_
inertia=estimator.inertia_

print (lable_pred) #各類別
print (centroids)
print (inertia)#總和
 
for i in range(len(data)):
    if int(lable_pred[i])==0:
        plt.scatter(data[i][0],data[i][1],color='red')
    if int(lable_pred[i])==1:
        plt.scatter(data[i][0],data[i][1],color='black')
    if int(lable_pred[i])==2:
        plt.scatter(data[i][0],data[i][1],color='blue')
plt.show()
# Out:
# [[0.46341747 0.44102762]
#  [0.99308228 0.0464983 ]
#  [0.1216393  0.17181861]
#  [0.69461333 0.6054773 ]
#  [0.90205956 0.62025688]
#  [0.74586357 0.88311855]
#  [0.47736307 0.12826312]
#  [0.92503769 0.49955919]
#  [0.31589409 0.77676449]
#  [0.04556657 0.16924224]]
# [1 0 2 1 0 1 2 0 1 2]
# [[0.94005984 0.38877145]
#  [0.55494711 0.67659699]
#  [0.21485632 0.15644132]]
# 0.5296593555430716
